# %% [markdown]
# # Assignment I
#
# I have been unsuccesfull in executing multiple steps of the assignment.
#
# 1. I could not make my object acess the database or exhibit the updated database.
# 2. I was unable to call for my .rb objetcs through my jupyter notebook.
# 3. I stil struggle with the overall structure of the code, which should ideally consist of the three objects containing the paramters and methods; the main body of the code would then utilize these three objects to create the database and perform the operations.
#
# I tried to use the load_file function name suggested in the text, but could not get the syntax to run correctly.
#
# Moreover, I also struggle with finding the right terms to search for appropriate solutions online.
#
# I am not expecting a decent grade for this assignment. In fact I am not sure if I am even going to pass it. However, could help me understand the following questions.
#
# 1. Do I have to create an instance method to upload each line of the code into an object? If yes, how do I call for it in the main code?
# 2. How does the code know where to find the file?
# 3. Can we call a method that belongs to one specific class from a different one?
#
# I should have addressed my mistakes from the last exam of the introductory course about the file access. I think that would have given me atleast the correct approach to organize the structure of this assignment.

# %%
class Seed_stock

  attr_accessor :Seed_stock  
  attr_accessor :Mutant_gene_ID
  attr_accessor :Last_planted
  attr_accessor :Storage
  attr_accessor :g_remaining
  attr_accessor :amount_planted
  attr_accessor :new_weight
  
  def initialize (
    this_Seed_stock = "name of seed stock", 
    this_Mutant_gene_ID = "0", 
    this_Last_planted = "00000000",
    this_storage = "abc1",
    this_g_remaining = 0,
    this_amount_planted = 7,
    this_new_weight = 0
    ) # get a name from the "new" call, or set a default
    
    @Seed_stock = this_Seed_stock
    @Mutant_gene_ID = this_Mutant_gene_ID
    @Last_planted = this_Last_planted
    @Storage = this_storage
    @g_remaining = this_g_remaining
    @amount_planted = this_amount_planted
    @new_weight = this_new_weight
  
     def new_g_remaining
      @new_weight = @g_remaining - @amount_planted
       if @new_weight < 1
         puts "we have run out of Seed Stock for #@Mutant_gene_ID"
       else
         puts "the remaining weight of seeds is #@new_weight for #@Mutant_gene_ID"
       end
       end
    end
end

#________________________________________________________________________________________
  
  s1 = Seed_stock.new(
  "A334", 
  "AT1G69120", 
  "5/7/2014", "cama2", 28)
  
  s2 = Seed_stock.new(
  "A348", 
  "AT4G36920", 
  "3/11/2013", "cama25", 12)

  s3 = Seed_stock.new(
  "B3334", 
  "AT4G36920", 
  "5/7/2014", "cama25", 28)

  s4 = Seed_stock.new(
  "A51", 
  "AT1G30950", 
  "9/2/2013", "cama25", 5)
  
  s5 = Seed_stock.new(
  "B52", 
  "AT5G20240", 
  "8/11/2012", "cama16", 7)

puts s1.Seed_stock, s1.Mutant_gene_ID, s1.Last_planted, s1.Storage, s1.g_remaining
puts s2.Seed_stock, s2.Mutant_gene_ID, s2.Last_planted, s2.Storage, s2.g_remaining
puts s3.Seed_stock, s3.Mutant_gene_ID, s3.Last_planted, s3.Storage, s3.g_remaining
puts s4.Seed_stock, s4.Mutant_gene_ID, s4.Last_planted, s4.Storage, s4.g_remaining
puts s5.Seed_stock, s5.Mutant_gene_ID, s5.Last_planted, s5.Storage, s5.g_remaining
  
#puts;

# call instance methods
a = s1.new_g_remaining()
b = s2.new_g_remaining()
c = s3.new_g_remaining()
d = s4.new_g_remaining()
e = s5.new_g_remaining()
puts a, b, c, d, e
# Out:
# A334
# AT1G69120
# 5/7/2014
# cama2
# 28
# A348
# AT4G36920
# 3/11/2013
# cama25
# 12
# B3334
# AT4G36920
# 5/7/2014
# cama25
# 28
# A51
# AT1G30950
# 9/2/2013
# cama25
# 5
# B52
# AT5G20240
# 8/11/2012
# cama16
# 7
# the remaining weight of seeds is 21 for AT1G69120
# the remaining weight of seeds is 5 for AT4G36920
# the remaining weight of seeds is 21 for AT4G36920
# we have run out of Seed Stock for AT1G30950
# we have run out of Seed Stock for AT5G20240

# %%
class Gene_information
  
  attr_accessor :Gene_ID
  attr_accessor :Gene_name
  attr_accessor :Mutant_phenotype

  
  def initialize (params = {}) 
  @Gene_ID = params.fetch(:Gene_ID, 'Some Person')
  @Gene_name = params.fetch(:Gene_name, 'Gene name')
  @Mutant_phenotype = params.fetch(:Mutant_phenotype, 'Mutant phenotype')

  end
end

  g1 = Gene_information.new(
  :Gene_ID => "AT1G69120", 
  :Gene_name => "ap1", 
  :Mutant_phenotype => "meristems replace first and second whorl")
  
  g2 = Gene_information.new(
  :Gene_ID => "AT4G36920", 
  :Gene_name => "ap2", 
  :Mutant_phenotype => "first whorl carpels, second whorl stamens")

  g3 = Gene_information.new(
  :Gene_ID => "AT3G54340", 
  :Gene_name => "ap3", 
  :Mutant_phenotype => "second whorl sepals, third whorl carpels") 

  g4 = Gene_information.new(
  :Gene_ID => "AT1G30950", 
  :Gene_name => "ufo", 
  :Mutant_phenotype => "second whorl sepaloidy, third whorl missing or carpeloid")

  g5 = Gene_information.new(
  :Gene_ID => "AT5G20240", 
  :Gene_name => "pi", 
  :Mutant_phenotype => "second whorl sepals, third whorl carpels")

puts g1.Gene_ID, g1.Gene_name, g1.Mutant_phenotype
puts g2.Gene_ID, g2.Gene_name, g2.Mutant_phenotype
puts g3.Gene_ID, g3.Gene_name, g3.Mutant_phenotype
puts g4.Gene_ID, g4.Gene_name, g4.Mutant_phenotype
puts g5.Gene_ID, g5.Gene_name, g5.Mutant_phenotype
# Out:
# AT1G69120
# ap1
# meristems replace first and second whorl
# AT4G36920
# ap2
# first whorl carpels, second whorl stamens
# AT3G54340
# ap3
# second whorl sepals, third whorl carpels
# AT1G30950
# ufo
# second whorl sepaloidy, third whorl missing or carpeloid
# AT5G20240
# pi
# second whorl sepals, third whorl carpels

# %%
class Cross_data
  attr_accessor :Parent_1
  attr_accessor :Parent_2
  attr_accessor :F2_wild
  attr_accessor :F2_P1
  attr_accessor :F2_P2
  attr_accessor :F2_P1P2
  attr_accessor :x_sq
  attr_accessor :sum
  
def initialize (params = {}) 
  @Parent_1 = params.fetch(:Parent_1, nil)
  @Parent_2 = params.fetch(:Parent_2, nil)
  @F2_wild = params.fetch(:F2_wild, nil)
  @F2_P1 = params.fetch(:F2_P1, nil)
  @F2_P2 = params.fetch(:F2_P2, nil)
  @F2_P1P2 = params.fetch(:F2_P1P2, nil)
  @x_sq = params.fetch(:x_sq, nil)
  @F2_wild = @F2_wild.to_f
  @F2_P1 = @F2_P1.to_f
  @F2_P2 = @F2_P2.to_f
  @F2_P1P2 = @F2_P1P2.to_f
  @sum = params.fetch(:sum, nil)
    
  def chi_square
    sum = self.F2_wild + self.F2_P1 + self.F2_P2 + self.F2_P1P2
    puts sum
    exp_F2_wild = sum*9/16
    puts exp_F2_wild
    #return exp_F2_wild
    exp_F2_P1 = sum*3/16
    puts exp_F2_P1
    exp_F2_P2 = sum*3/16
    puts exp_F2_P2
    #return exp_F2_P2
    exp_F2_P1P2 = sum*1/16
    puts exp_F2_P1P2
    
    x_sq = ((self.F2_wild-exp_F2_wild)**2/exp_F2_wild) + ((self.F2_P1-exp_F2_P1)**2/exp_F2_P1) + ((self.F2_P2-exp_F2_P2)**2/exp_F2_P2) + ((self.F2_P1P2-exp_F2_P1P2)**2/exp_F2_P1P2)
    if x_sq > 7.8
      $stderr.puts "#{self.Parent_1} is linked to #{self.Parent_2} with a chi score of #{x_sq}"
    end
    end
end
end

  c1 = Cross_data.new(
  :Parent_1 => "A334", 
  :Parent_2 => "A348", 
  :F2_wild => 110, :F2_P1 => 33, :F2_P2 => 38, :F2_P1P2 => 11)
  
  c2 = Cross_data.new(
  :Parent_1 => "A348", 
  :Parent_2 => "B3334", 
  :F2_wild => 80, :F2_P1 => 26, :F2_P2 => 29, :F2_P1P2 => 8) 
  
  c3 = Cross_data.new(
  :Parent_1 => "B3334", 
  :Parent_2 => "A51", 
  :F2_wild => 99, :F2_P1 => 36, :F2_P2 => 34, :F2_P1P2 => 12) 
  
  c4 = Cross_data.new(
  :Parent_1 => "A51", 
  :Parent_2 => "B52", 
  :F2_wild => 152, :F2_P1 => 26, :F2_P2 => 22, :F2_P1P2 => 2) 
  
  c5 = Cross_data.new(
  :Parent_1 => "B52", 
  :Parent_2 => "A334", 
  :F2_wild => 75, :F2_P1 => 22, :F2_P2 => 30, :F2_P1P2 => 7) 
  
  puts c1.Parent_1, c1.Parent_2, c1.F2_wild, c1.F2_P1, c1.F2_P2, c1.F2_P1P2
  puts c2.Parent_1, c2.Parent_2, c2.F2_wild, c2.F2_P1, c2.F2_P2, c2.F2_P1P2
  puts c3.Parent_1, c3.Parent_2, c3.F2_wild, c3.F2_P1, c3.F2_P2, c3.F2_P1P2
  puts c4.Parent_1, c4.Parent_2, c4.F2_wild, c4.F2_P1, c4.F2_P2, c4.F2_P1P2
  puts c5.Parent_1, c5.Parent_2, c5.F2_wild, c5.F2_P1, c5.F2_P2, c5.F2_P1P2 
  
  x_sq_Wild = c1.chi_square()
  x_sq_P1 = c2.chi_square() 
  x_sq_P2 = c3.chi_square()
  x_sq_P1P2 = c4.chi_square()
  x_sq_P1P2 = c5.chi_square()
# Out:
# A334
# A348
# 110.0
# 33.0
# 38.0
# 11.0
# A348
# B3334
# 80.0
# 26.0
# 29.0
# 8.0
# B3334
# A51
# 99.0
# 36.0
# 34.0
# 12.0
# A51
# B52
# 152.0
# 26.0
# 22.0
# 2.0
# B52
# A334
# 75.0
# 22.0
# 30.0
# 7.0
# 192.0
# 108.0
# 36.0
# 36.0
# 12.0
# 143.0
# 80.4375
# 26.8125
# 26.8125
# 8.9375
# 181.0
# 101.8125
# 33.9375
# 33.9375
# 11.3125
# 202.0
# 113.625
# 37.875
# 37.875
# 12.625
# A51 is linked to B52 with a chi score of 32.27942794279428
# 134.0
# 75.375
# 25.125
# 25.125
# 8.375

# %%
class Cross_data
  attr_accessor :Parent_1
  attr_accessor :Parent_2
  attr_accessor :F2_wild
  attr_accessor :F2_P1
  attr_accessor :F2_P2
  attr_accessor :F2_P1P2
  attr_accessor :x_sq
  attr_accessor :sum
  
def initialize (params = {}) 
  @Parent_1 = params.fetch(:Parent_1, nil)
  @Parent_2 = params.fetch(:Parent_2, nil)
  @F2_wild = params.fetch(:F2_wild, nil)
  @F2_P1 = params.fetch(:F2_P1, nil)
  @F2_P2 = params.fetch(:F2_P2, nil)
  @F2_P1P2 = params.fetch(:F2_P1P2, nil)
  @x_sq = params.fetch(:x_sq, nil)
  @F2_wild = @F2_wild.to_f
  @F2_P1 = @F2_P1.to_f
  @F2_P2 = @F2_P2.to_f
  @F2_P1P2 = @F2_P1P2.to_f
  @sum = params.fetch(:sum, nil)
  @allcrosses = []
  crossfile = params.fetch(:crossfile)
  self.load_cross_data(crossfile)
  
  def load_cross_data(crossfile)
   
    crossfile = File.open(cross_data.tsv, 'r')
    
    crossfile.readlines.each do |line|
      line.strip!
     
      self.Parent_1, self.Parent_2, self.F2_wild, self.F2_P1, self.F2_P2, self.F2_P1P2 = line.split("\t")

      cross = cross.new({
        :Parent_1 => self.Parent_1,
        :Parent_2 => self.Parent_2,
        :F2_wild => self.F2_wild,
        :F2_P1 => self.F2_P1,
        :F2_P2 => self.F2_P2,
        :F2_P1P2 => self.F2_P1P2
      })
      @allcrosses |= [cross]
      return @allcrosses
  
  
    
  def chi_square
    sum = self.F2_wild + self.F2_P1 + self.F2_P2 + self.F2_P1P2
    puts sum
    exp_F2_wild = sum*9/16
    puts exp_F2_wild
    #return exp_F2_wild
    exp_F2_P1 = sum*3/16
    puts exp_F2_P1
    exp_F2_P2 = sum*3/16
    puts exp_F2_P2
    #return exp_F2_P2
    exp_F2_P1P2 = sum*1/16
    puts exp_F2_P1P2
    
    x_sq = ((self.F2_wild-exp_F2_wild)**2/exp_F2_wild) + ((self.F2_P1-exp_F2_P1)**2/exp_F2_P1) + ((self.F2_P2-exp_F2_P2)**2/exp_F2_P2) + ((self.F2_P1P2-exp_F2_P1P2)**2/exp_F2_P1P2)
    #puts "this is #@x_sq"
    puts x_sq
    end
    end end
end
end

x_sq_P1P2 = cross.load_cross_data()
# Out:
# (eval):29: formal argument cannot be an instance variable
# ...ross_data(crossfile,@allcrosses)
# ...                    ^~~~~~~~~~~
# NameError: undefined local variable or method `cross' for main:Object
# (pry):432:in `<main>'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:290:in `eval'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:290:in `evaluate_ruby'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:659:in `handle_line'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:261:in `block (2 levels) in eval'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:260:in `catch'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:260:in `block in eval'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:259:in `catch'
# /var/lib/gems/2.5.0/gems/pry-0.13.1/lib/pry/pry_instance.rb:259:in `eval'
# /var/lib/gems/2.5.0/gems/iruby-0.4.0/lib/iruby/backend.rb:66:in `eval'
# ...
